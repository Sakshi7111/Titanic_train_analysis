# %% [markdown]
# # READ THE DATA(Q7)

# %%
import pandas as pd

# %%
import os

# %%
os.chdir(r"Downloads")

# %%
titanic_train_data=pd.read_csv("titanic_train.csv")

# %%
titanic_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # COUNTPLOT FOR SURVIVED OR NOT SURVIVED(Q1)

# %%
import seaborn as sns

# %%
sns.countplot("Survived",data=titanic_train_data,palette='nipy_spectral')

# %% [markdown]
# # COUNTPLOT FOR SURVIVED OR NOT SURVIVED SHOWING SEX USING HUE COMMAND(Q2)

# %%
sns.countplot('Survived',data=titanic_train_data,hue='Sex',palette='ocean')

# %% [markdown]
# # COUNTPLOT FOR SURVIVED OR NOT SURVIVED SHOWING PASSENGER CLASS USING HUE COMMAND (Q3)

# %%
sns.countplot('Survived',data=titanic_train_data,hue='Pclass',palette='prism')

# %% [markdown]
# # COUNTPLOT FOR SIBSP IN A GRAPH REPRESENTATION(Q4)

# %%
sns.countplot("SibSp",data=titanic_train_data)

# %% [markdown]
# # BOXPLOT FOR PASSENGER CLASS AND AGE SHOWING X=PCLASS AND Y=AGE ALONG WITH OUTLIARS(Q5)

# %%
sns.boxplot(x="Pclass",y="Age",data=titanic_train_data,palette="rainbow")

# %% [markdown]
# # SHOW 5 DATA OF TITANIC_TRAIN FROM BOTH TOP AND BOTTOM(Q6)

# %%
titanic_train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # BARPLOT FOR AGE AND SEX SHOWING X=AGE AND Y=SEX IN A GRAPH REPRESNTATION(Q8)

# %%
sns.barplot(y='Sex',x='Age',data=titanic_train_data,palette='gnuplot2')

# %% [markdown]
# # SHOWING DATATYPES OF ALL FEATURES OF TITANIC_TRAIN(Q9)

# %%
titanic_train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # PAIRLOT FOR CO-RELATION BETWEEN ALL FEATURES SHOWING LINEAR REGREATION LINE(Q10)

# %%
sns.pairplot(titanic_train_data,kind='reg')

# %%
titanic_train_data.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# # HEAT MAP FOR ALL FEATURES OF TITANIC_TRAIN(Q11)

# %%
sns.heatmap(titanic_train_data.corr())
